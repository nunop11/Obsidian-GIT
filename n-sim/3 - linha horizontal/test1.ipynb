# %%
import pygame as pg
import pygame.draw as dw
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# Out:
# pygame 2.6.0 (SDL 2.28.4, Python 3.11.0)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# # Integração de Verlet
# Do tipo
# $$\frac{dr}{dt} = f(x, t)$$
#
# Para uma eq de movimento podemos ter $\frac{d^2\vec r}{dt^2}=f(\vec r,\frac{d\vec r}{dt}, t)$, que podemos resolver como:
# $$\begin{cases}
# \frac{d\vec r}{dt}=\vec v\\
# \frac{d\vec v}{dt}= f(\vec r,\vec v,t)
# \end{cases}$$

# %%
# Aqui, a forma como se coloca r na função f() depende completamente de como f está definida e funciona

def RK4_2var(f, xi, yi, a, b, N):
    x, y = np.zeros(N), np.zeros(N)
    x[0] = xi
    y[0] = yi
    r = np.array([x,y]).T # transposta para cada linha ser um ponto (x,y)
    h = (b-a)/N
    t = np.linspace(a,b,N)
    for i in range(1, N):
        k1 = h * f(*r[i-1], t[i-1])
        k2 = h * f(*r[i-1] + 0.5*k1, t[i-1] + 0.5*h)
        k3 = h * f(*r[i-1] + 0.5*k2, t[i-1] + 0.5*h)
        k4 = h * f(*r[i-1] + k3, t[i-1] + h)

        r[i] = r[i-1] + 1/6*(k1 + 2*k2 + 2*k3 + k4)
    
    return (r.T), t

# %% [markdown]
# # Caixa com Gravidade apenas
#
# $$f = \vec a = (0,10)$$

# %%
def RK4(f, xi, yi, a, b, N):
    x, y = np.zeros(N), np.zeros(N)
    x[0] = xi
    y[0] = yi
    r = np.array([x,y]).T # transposta para cada linha ser um ponto (x,y)
    h = (b-a)/N
    t = np.linspace(a,b,N)
    for i in range(1, N):
        k1 = h * f(*r[i-1], t[i-1])
        k2 = h * f(*r[i-1] + 0.5*k1, t[i-1] + 0.5*h)
        k3 = h * f(*r[i-1] + 0.5*k2, t[i-1] + 0.5*h)
        k4 = h * f(*r[i-1] + k3, t[i-1] + h)

        r[i] = r[i-1] + 1/6*(k1 + 2*k2 + 2*k3 + k4)
    return (r.T), t

def animate():
    L = 1000
    disp = pg.display.set_mode((L,L), pg.RESIZABLE)
    pg.display.set_caption("Teste #1")
    clk = pg.time.Clock()
    FPS = 60

    yL = 0.75*L
    R = L/100
    r = np.array([R,yL/2])
    v = np.array([50,-50])
    sol = np.array([r[0], r[1], v[0], v[1]])
    dw.line(disp, (255,255,255), (0,yL), (L,L-yL), 5)

    a = np.array([0,-10]) 

    colorTraj = [100,100,100]
    points = [(r[0],r[1])]

    m = 1 # massa (kg)
    
    N = 500
    dt = 100/N
    
    e = 0.99

    def f(x,y,vx,vy,t):
        fx = 0
        fy = 10
        return np.array([vx, vy, fx, fy], float)
        

    for i in range(N):
        for event in pg.event.get():
            if event.type == pg.QUIT:
                return None
            if event.type == pg.VIDEORESIZE:
                disp = pg.display.set_mode((event.w, event.h),pg.RESIZABLE)
                L = np.min([event.h, event.w])
                yL = 0.75*L
        disp.fill((0,0,0)) # refresh fundo da pagina

        dw.line(disp, (255,255,255), (0,yL), (L,yL), 5)
        
        t = i*dt
        k1 = dt * f(*sol, t)
        k2 = dt * f(*sol + 0.5*k1, t + 0.5*dt)
        k3 = dt * f(*sol + 0.5*k2, t + 0.5*dt)
        k4 = dt * f(*sol + k3, t + dt)

        sol = sol + 1/6*(k1 + 2*k2 + 2*k3 + k4)
        r = sol[:2]
        v = sol[2:]
        # paredes
        if r[0] <= R :
            v[0] *= -1*np.sqrt(e)
            r[0] =  - r[0] + 2*R
        elif r[0] >= L-R:
            v[0] *= -1*np.sqrt(e)
            r[0] = 2*L - r[0] - 2*R
        if r[1] <= R :
            v[1] *= -1*np.sqrt(e)
            r[1] =  - r[1] + 2*R
        if r[1] >= L-R:
            v[1] *= -1*np.sqrt(e)
            r[1] = 2*L - r[1] - 2*R
        # linha de baixo
        if r[1] >= yL-R:
            v[1] *= -1*np.sqrt(e)
            r[1] = 2*yL - r[1] - 2*R
        sol = np.array([r[0], r[1], v[0], v[1]])
       
        points.append((r[0],r[1]))
        if i % 3 == 0: # 0,3,6,9 
            if colorTraj[0] + 2 > 255: colorTraj[0] = 0
            colorTraj[0] += 2
        if i-1 % 3 == 0: # 1,4,7,10
            if colorTraj[1] + 4 > 255: colorTraj[1] = 0
            colorTraj[1] += 4
        if i-2 % 3 == 0: # 2,5,8,11
            if colorTraj[2] - 2 < 0: colorTraj[2] = 255
            colorTraj[2] -= 2
        dw.lines(disp, colorTraj, False, points, 2)
        dw.circle(disp, (255,255,255), (r[0], r[1]), R, 0)
        pg.display.update()
        clk.tick(FPS)
        x3 = pg.surfarray.pixels3d(disp)
        array = np.uint8(x3)
        im = Image.fromarray(array)
        im = im.save(f'./photos/{i:04d}.png', 'PNG')



animate()
pg.quit()

# %% [markdown]
# # Caixa com Gravidade e Resistência do Ar
# $$f = \vec a- \vec F_{ar} = (0,10) - \frac{b}{m}\vec v$$

# %%
def RK4(f, xi, yi, a, b, N):
    x, y = np.zeros(N), np.zeros(N)
    x[0] = xi
    y[0] = yi
    r = np.array([x,y]).T # transposta para cada linha ser um ponto (x,y)
    h = (b-a)/N
    t = np.linspace(a,b,N)
    for i in range(1, N):
        k1 = h * f(*r[i-1], t[i-1])
        k2 = h * f(*r[i-1] + 0.5*k1, t[i-1] + 0.5*h)
        k3 = h * f(*r[i-1] + 0.5*k2, t[i-1] + 0.5*h)
        k4 = h * f(*r[i-1] + k3, t[i-1] + h)

        r[i] = r[i-1] + 1/6*(k1 + 2*k2 + 2*k3 + k4)
    return (r.T), t

def animate():
    L = 1000
    disp = pg.display.set_mode((L,L), pg.RESIZABLE)
    pg.display.set_caption("Teste #1")
    clk = pg.time.Clock()
    FPS = 60

    yL = 0.75*L
    R = L/100
    r = np.array([R,yL-R])
    v = np.array([100,-100])
    sol = np.array([r[0], r[1], v[0], v[1]])
    dw.line(disp, (255,255,255), (0,yL), (L,L-yL), 5)

    a = np.array([0,-10]) 

    colorTraj = [100,100,100]
    points = [(r[0],r[1])]

    b = 0.5 # constante de força de res ar
    m = 2 # massa (kg)
    
    N = 500
    dt = 100/N
    
    e = 0.99

    def f(x,y,vx,vy,t):
        fx = - b/m * vx
        fy = 10 - b/m * vy 
        return np.array([vx, vy, fx, fy], float)
        

    for i in range(N):
        for event in pg.event.get():
            if event.type == pg.QUIT:
                return None
            if event.type == pg.VIDEORESIZE:
                disp = pg.display.set_mode((event.w, event.h),pg.RESIZABLE)
                L = np.min([event.h, event.w])
                yL = 0.75*L
        disp.fill((0,0,0)) # refresh fundo da pagina

        dw.line(disp, (255,255,255), (0,yL), (L,yL), 5)
        
        t = i*dt
        k1 = dt * f(*sol, t)
        k2 = dt * f(*sol + 0.5*k1, t + 0.5*dt)
        k3 = dt * f(*sol + 0.5*k2, t + 0.5*dt)
        k4 = dt * f(*sol + k3, t + dt)

        sol = sol + 1/6*(k1 + 2*k2 + 2*k3 + k4)
        r = sol[:2]
        v = sol[2:]
        # paredes
        if r[0] <= R :
            v[0] *= -1*np.sqrt(e)
            r[0] =  - r[0] + 2*R
        elif r[0] >= L-R:
            v[0] *= -1*np.sqrt(e)
            r[0] = 2*L - r[0] - 2*R
        if r[1] <= R :
            v[1] *= -1*np.sqrt(e)
            r[1] =  - r[1] + 2*R
        if r[1] >= L-R:
            v[1] *= -1*np.sqrt(e)
            r[1] = 2*L - r[1] - 2*R
        # linha de baixo
        if r[1] >= yL-R:
            v[1] *= -1*np.sqrt(e)
            r[1] = 2*yL - r[1] - 2*R
        sol = np.array([r[0], r[1], v[0], v[1]])
       
        points.append((r[0],r[1]))
        if i % 3 == 0: # 0,3,6,9 
            if colorTraj[0] + 2 > 255: colorTraj[0] = 0
            colorTraj[0] += 2
        if i-1 % 3 == 0: # 1,4,7,10
            if colorTraj[1] + 4 > 255: colorTraj[1] = 0
            colorTraj[1] += 4
        if i-2 % 3 == 0: # 2,5,8,11
            if colorTraj[2] - 2 < 0: colorTraj[2] = 255
            colorTraj[2] -= 2
        dw.lines(disp, colorTraj, False, points, 2)
        dw.circle(disp, (255,255,255), (r[0], r[1]), R, 0)
        pg.display.update()
        clk.tick(FPS)
        x3 = pg.surfarray.pixels3d(disp)
        array = np.uint8(x3)
        im = Image.fromarray(array)
        im = im.save(f'./photos/{i:04d}.png', 'PNG')



animate()
pg.quit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\ProgramData\anaconda3\envs\computacional\Lib\site-packages\PIL\ImageFile.py:536, in _save(im, fp, tile, bufsize)
#     535 try:
# --> 536     fh = fp.fileno()
#     537     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 111
#     106         im = Image.fromarray(array)
#     107         im = im.save(f'./photos/{i:04d}.png', 'PNG')
# --> 111 animate()
#     112 pg.quit()
#
# Cell In[3], line 107, in animate()
#     105 array = np.uint8(x3)
#     106 im = Image.fromarray(array)
# --> 107 im = im.save(f'./photos/{i:04d}.png', 'PNG')
#
# File c:\ProgramData\anaconda3\envs\computacional\Lib\site-packages\PIL\Image.py:2439, in Image.save(self, fp, format, **params)
#    2436         fp = builtins.open(filename, "w+b")
#    2438 try:
# -> 2439     save_handler(self, fp, filename)
#    2440 except Exception:
#    2441     if open_fp:
#
# File c:\ProgramData\anaconda3\envs\computacional\Lib\site-packages\PIL\PngImagePlugin.py:1402, in _save(im, fp, filename, chunk, save_all)
#    1398     im = _write_multiple_frames(
#    1399         im, fp, chunk, rawmode, default_image, append_images
#    1400     )
#    1401 if im:
# -> 1402     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#    1404 if info:
#    1405     for info_chunk in info.chunks:
#
# File c:\ProgramData\anaconda3\envs\computacional\Lib\site-packages\PIL\ImageFile.py:540, in _save(im, fp, tile, bufsize)
#     538     _encode_tile(im, fp, tile, bufsize, fh)
#     539 except (AttributeError, io.UnsupportedOperation) as exc:
# --> 540     _encode_tile(im, fp, tile, bufsize, None, exc)
#     541 if hasattr(fp, "flush"):
#     542     fp.flush()
#
# File c:\ProgramData\anaconda3\envs\computacional\Lib\site-packages\PIL\ImageFile.py:559, in _encode_tile(im, fp, tile, bufsize, fh, exc)
#     556 if exc:
#     557     # compress to Python file-compatible object
#     558     while True:
# --> 559         errcode, data = encoder.encode(bufsize)[1:]
#     560         fp.write(data)
#     561         if errcode:
#
# KeyboardInterrupt:
