# %%
import pygame as pg
import pygame.draw as dw
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# Out:
# pygame 2.6.0 (SDL 2.28.4, Python 3.11.0)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# # RK4
# Do tipo
# $$\frac{dr}{dt} = f(x, t)$$
#
# Para uma eq de movimento podemos ter $\frac{d^2\vec r}{dt^2}=f(\vec r,\frac{d\vec r}{dt}, t)$, que podemos resolver como:
# $$\begin{cases}
# \frac{d\vec r}{dt}=\vec v\\
# \frac{d\vec v}{dt}= f(\vec r,\vec v,t)
# \end{cases}$$

# %%
# Aqui, a forma como se coloca r na função f() depende completamente de como f está definida e funciona

def RK4_2var(f, xi, yi, a, b, N):
    x, y = np.zeros(N), np.zeros(N)
    x[0] = xi
    y[0] = yi
    r = np.array([x,y]).T # transposta para cada linha ser um ponto (x,y)
    h = (b-a)/N
    t = np.linspace(a,b,N)
    for i in range(1, N):
        k1 = h * f(*r[i-1], t[i-1])
        k2 = h * f(*r[i-1] + 0.5*k1, t[i-1] + 0.5*h)
        k3 = h * f(*r[i-1] + 0.5*k2, t[i-1] + 0.5*h)
        k4 = h * f(*r[i-1] + k3, t[i-1] + h)

        r[i] = r[i-1] + 1/6*(k1 + 2*k2 + 2*k3 + k4)
    
    return (r.T), t

# %% [markdown]
# # Círculo com Massa a andar à volta

# %%
def animate():
    L = 1000
    disp = pg.display.set_mode((L,L), pg.RESIZABLE)
    pg.display.set_caption("Teste #1")
    clk = pg.time.Clock()
    FPS = 60

    # centro e raio de circulo
    C = np.array([L/2,L/2])
    Wc = 10 # espessura do circulo em px
    Rc = L/12*4 - Wc
    dw.circle(disp, (255,255,255), C, Rc, 10)

    # bola
    R = L/100
    r = C + np.array([50,0])
    v = np.array([0,-10])
    sol = np.array([r[0], r[1], v[0], v[1]])

    # massa externa
    Rext = L/50
    rext = np.array([L/2, L/16])
    mExt = 1e6
    dw.circle(disp, (255,100,100), rext, Rext, 0)

    a = np.array([0,-50]) 

    colorTraj = [100,100,100]
    points = [(r[0],r[1])]

    m = 2 # massa (kg)
    
    N = 500
    dt = 100/N
    
    e = 1

    rotMat = lambda th: np.array([[np.cos(th),-np.sin(th)],[np.sin(th),np.cos(th)]])
    dth = 2*np.pi*3/N 
    matRotExt = rotMat(dth) # matriz para mover massa ext em cada iteração

    # !! alterei a função para incluir a posição da massa externa
    def f(x,y,vx,vy,t,rext):
        r = np.array([x,y])
        F = m*mExt/np.linalg.norm(r-rext)**2*10
        delta = rext - r
        th = np.arctan2(delta[1],delta[0])
        fx = F*np.cos(th)
        fy = F*np.sin(th)
        return np.array([vx, vy, fx, fy], float)
        

    for i in range(N):
        for event in pg.event.get():
            if event.type == pg.QUIT:
                return None
            if event.type == pg.VIDEORESIZE:
                disp = pg.display.set_mode((event.w, event.h),pg.RESIZABLE)
                L = np.min([event.h, event.w])
                yL = 0.75*L
        disp.fill((0,0,0)) # refresh fundo da pagina

        dw.circle(disp, (255,255,255), C, Rc, 10)

        rext -= C 
        rext = matRotExt @ rext
        rext += C
        dw.circle(disp, (255,100,100), rext, Rext, 0)

        
        t = i*dt
        # !! alterei a função para incluir a posição da massa externa
        k1 = dt * f(*sol, t, rext)
        k2 = dt * f(*sol + 0.5*k1, t + 0.5*dt, rext)
        k3 = dt * f(*sol + 0.5*k2, t + 0.5*dt, rext)
        k4 = dt * f(*sol + k3, t + dt, rext)

        sol = sol + 1/6*(k1 + 2*k2 + 2*k3 + k4)
        r = sol[:2]
        v = sol[2:]
        # paredes circulo
        if np.linalg.norm(r-C) >= Rc - 2*R :
            th = np.arctan2(v[0], v[1])
            beta = np.arctan2((r-C)[1], (r-C)[0])
            angIn = th + beta
            matriz = rotMat(2*angIn) # matriz de rotação
            v = matriz @ v # rodar velocidade
            v *= np.sqrt(e) # atenuação da energia cinética por um fator e
            r = C + (Rc - 2*R) * (r-C)/np.linalg.norm(r-C)
            
        sol = np.array([r[0], r[1], v[0], v[1]])

        points.append((r[0],r[1]))
        if i % 3 == 0: # 0,3,6,9 
            if colorTraj[0] + 2 > 255: colorTraj[0] = 0
            colorTraj[0] += 2
        if i-1 % 3 == 0: # 1,4,7,10
            if colorTraj[1] + 4 > 255: colorTraj[1] = 0
            colorTraj[1] += 4
        if i-2 % 3 == 0: # 2,5,8,11
            if colorTraj[2] - 2 < 0: colorTraj[2] = 255
            colorTraj[2] -= 2
        dw.lines(disp, colorTraj, False, points, 2)
        dw.circle(disp, (255,255,255), (r[0], r[1]), R, 0)
        pg.display.update()
        clk.tick(FPS)
        x3 = pg.surfarray.pixels3d(disp)
        array = np.uint8(x3)
        im = Image.fromarray(array)
        im = im.save(f'./photos/{i:04d}.png', 'PNG')


animate()
pg.quit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\ProgramData\anaconda3\envs\computacional\Lib\site-packages\PIL\ImageFile.py:536, in _save(im, fp, tile, bufsize)
#     535 try:
# --> 536     fh = fp.fileno()
#     537     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 113
#     109         im = Image.fromarray(array)
#     110         im = im.save(f'./photos/{i:04d}.png', 'PNG')
# --> 113 animate()
#     114 pg.quit()
#
# Cell In[4], line 110, in animate()
#     108 array = np.uint8(x3)
#     109 im = Image.fromarray(array)
# --> 110 im = im.save(f'./photos/{i:04d}.png', 'PNG')
#
# File c:\ProgramData\anaconda3\envs\computacional\Lib\site-packages\PIL\Image.py:2439, in Image.save(self, fp, format, **params)
#    2436         fp = builtins.open(filename, "w+b")
#    2438 try:
# -> 2439     save_handler(self, fp, filename)
#    2440 except Exception:
#    2441     if open_fp:
#
# File c:\ProgramData\anaconda3\envs\computacional\Lib\site-packages\PIL\PngImagePlugin.py:1402, in _save(im, fp, filename, chunk, save_all)
#    1398     im = _write_multiple_frames(
#    1399         im, fp, chunk, rawmode, default_image, append_images
#    1400     )
#    1401 if im:
# -> 1402     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#    1404 if info:
#    1405     for info_chunk in info.chunks:
#
# File c:\ProgramData\anaconda3\envs\computacional\Lib\site-packages\PIL\ImageFile.py:540, in _save(im, fp, tile, bufsize)
#     538     _encode_tile(im, fp, tile, bufsize, fh)
#     539 except (AttributeError, io.UnsupportedOperation) as exc:
# --> 540     _encode_tile(im, fp, tile, bufsize, None, exc)
#     541 if hasattr(fp, "flush"):
#     542     fp.flush()
#
# File c:\ProgramData\anaconda3\envs\computacional\Lib\site-packages\PIL\ImageFile.py:559, in _encode_tile(im, fp, tile, bufsize, fh, exc)
#     556 if exc:
#     557     # compress to Python file-compatible object
#     558     while True:
# --> 559         errcode, data = encoder.encode(bufsize)[1:]
#     560         fp.write(data)
#     561         if errcode:
#
# KeyboardInterrupt:

# %% [markdown]
# # Círculo com 2 cargas externas, uma atrai e outra repele

# %%
def animate():
    L = 1000
    disp = pg.display.set_mode((L,L), pg.RESIZABLE)
    pg.display.set_caption("Teste #1")
    clk = pg.time.Clock()
    FPS = 60

    # centro e raio de circulo
    C = np.array([L/2,L/2])
    Wc = 10 # espessura do circulo em px
    Rc = L/12*4 - Wc
    dw.circle(disp, (255,255,255), C, Rc, 10)

    # bola
    R = L/100
    r = C + np.array([50,0])
    v = np.array([0,-10])
    sol = np.array([r[0], r[1], v[0], v[1]])

    # massa atratora
    Rat = L/50
    rat = np.array([L/2, L/16])
    mat = 1e5
    dw.circle(disp, (255,100,100), rat, Rat, 0)

    # massa repelente
    Rre = L/50
    rre = np.array([L/2, L/16*15])
    mre = -1e5 # se m<0 a bola torna-se repelente
    dw.circle(disp, (100,100,255), rre, Rre, 0)

    colorTraj = [100,100,100]
    points = [(r[0],r[1])]

    m = 2 # massa (kg)
    
    N = 500
    dt = 100/N
    
    e = 1

    rotMat = lambda th: np.array([[np.cos(th),-np.sin(th)],[np.sin(th),np.cos(th)]])
    dth = 2*np.pi*3/N 
    matRotExt = rotMat(dth) # matriz para mover massa ext em cada iteração

    # !! alterei a função para incluir a posição da massa externa
    def f(x,y,vx,vy,t,rat,rre):
        r = np.array([x,y])
        F_at = m*mat/np.linalg.norm(r-rat)**2*10
        delta_at = rat - r
        th_at = np.arctan2(delta_at[1],delta_at[0])
        F_re = m*mre/np.linalg.norm(r-rre)**2*10
        delta_re = rre - r
        th_re = np.arctan2(delta_re[1],delta_re[0])
        fx = F_at*np.cos(th_at) + F_re*np.cos(th_re)
        fy = F_at*np.sin(th_at) + F_re*np.sin(th_re)
        return np.array([vx, vy, fx, fy], float)
        

    for i in range(N):
        for event in pg.event.get():
            if event.type == pg.QUIT:
                return None
            if event.type == pg.VIDEORESIZE:
                disp = pg.display.set_mode((event.w, event.h),pg.RESIZABLE)
                L = np.min([event.h, event.w])
                yL = 0.75*L
        disp.fill((0,0,0)) # refresh fundo da pagina

        dw.circle(disp, (255,255,255), C, Rc, 10)

        rat -= C ; rre -= C
        rat = matRotExt @ rat ; rre = matRotExt @ rre
        rat += C ; rre += C
        dw.circle(disp, (255,100,100), rat, Rat, 0)
        dw.circle(disp, (100,100,255), rre, Rre, 0)

        t = i*dt
        # !! alterei a função para incluir a posição da massa externa
        k1 = dt * f(*sol, t, rat, rre)
        k2 = dt * f(*sol + 0.5*k1, t + 0.5*dt, rat, rre)
        k3 = dt * f(*sol + 0.5*k2, t + 0.5*dt, rat, rre)
        k4 = dt * f(*sol + k3, t + dt, rat, rre)

        sol = sol + 1/6*(k1 + 2*k2 + 2*k3 + k4)
        r = sol[:2]
        v = sol[2:]
        # paredes circulo
        if np.linalg.norm(r-C) >= Rc - 2*R :
            th = np.arctan2(v[0], v[1])
            beta = np.arctan2((r-C)[1], (r-C)[0])
            angIn = th + beta
            matriz = rotMat(2*angIn) # matriz de rotação
            v = matriz @ v # rodar velocidade
            v *= np.sqrt(e) # atenuação da energia cinética por um fator e
            r = C + (Rc - 2*R) * (r-C)/np.linalg.norm(r-C)
            
        sol = np.array([r[0], r[1], v[0], v[1]])

        points.append((r[0],r[1]))
        if i % 3 == 0: # 0,3,6,9 
            if colorTraj[0] + 2 > 255: colorTraj[0] = 0
            colorTraj[0] += 2
        if i-1 % 3 == 0: # 1,4,7,10
            if colorTraj[1] + 4 > 255: colorTraj[1] = 0
            colorTraj[1] += 4
        if i-2 % 3 == 0: # 2,5,8,11
            if colorTraj[2] - 2 < 0: colorTraj[2] = 255
            colorTraj[2] -= 2
        dw.lines(disp, colorTraj, False, points, 2)
        dw.circle(disp, (255,255,255), (r[0], r[1]), R, 0)
        pg.display.update()
        clk.tick(FPS)
        x3 = pg.surfarray.pixels3d(disp)
        array = np.uint8(x3)
        im = Image.fromarray(array)
        im = im.save(f'./photos/{i:04d}.png', 'PNG')


animate()
pg.quit()
